# %%
import pandas as pd

# %%
df = pd.read_csv('Combined(Mani).csv',encoding='latin1')

# %%
df
# Out:
#                   Chapter                                      Topic  \
# 0                   Basics  Step-by-step analysis of biological data
# 1                   Basics  Step-by-step analysis of biological data
# 2                   Basics  Step-by-step analysis of biological data
# 3                   Basics  Step-by-step analysis of biological data
# 4                   Basics  Step-by-step analysis of biological data
# 5                   Basics  Step-by-step analysis of biological data
# 6                   Basics  Step-by-step analysis of biological data
# 7                   Basics             Types of biological variables
# 8                   Basics             Types of biological variables
# 9                   Basics             Types of biological variables
# 10                  Basics             Types of biological variables
# 11                  Basics             Types of biological variables
# 12                  Basics             Types of biological variables
# ...

# %%
df['ChatAns'] = None  # or = 0 if you prefer numeric

# %%
count = 1
for question in df['Question']:
    print(question)
    df['ChatAns'].loc[df['Question'] == question] = count
    count += 1
# Out:
# What is the best way to analyze biological data?
# What is the most important thing to remember when analyzing data?
# What is the difference between a biological null hypothesis and an alternative hypothesis?
# If error bars in a graph are far apart, what does that mean?
# What does ANOVA assume?
# If ANOVA gives a p-value less than 0.05, what does it mean?
# What is the best way to present your results?
# What are the three types of biological variables?
# What is the best way to analyze a Likert scale item?
# What is the difference between circular, ratio, nominal, and ranked variables?
# How do you decide which variables to use in a statistical test?
# Why is it important to classify measurement variables correctly?
# What is dichotomizing, and why do some researchers use it?
# Why does choosing the right variable type matter in analysis?
# What is probability?
# How often will you need to calculate probabilities yourself?
# ...

# %%
df
# Out:
#                   Chapter                                      Topic  \
# 0                   Basics  Step-by-step analysis of biological data
# 1                   Basics  Step-by-step analysis of biological data
# 2                   Basics  Step-by-step analysis of biological data
# 3                   Basics  Step-by-step analysis of biological data
# 4                   Basics  Step-by-step analysis of biological data
# 5                   Basics  Step-by-step analysis of biological data
# 6                   Basics  Step-by-step analysis of biological data
# 7                   Basics             Types of biological variables
# 8                   Basics             Types of biological variables
# 9                   Basics             Types of biological variables
# 10                  Basics             Types of biological variables
# 11                  Basics             Types of biological variables
# 12                  Basics             Types of biological variables
# ...
